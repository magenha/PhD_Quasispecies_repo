# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random

# %%
#First, let us create a 1D random walker, with step constant in time s = 1

# %%
#Now we want to see some things. Like doing M iterations, what is the mean value at each moment of time. What is the mean quadratic distance to origin, and so.

M = 1000
s = 1
n_steps = 4000

x = np.zeros((M,n_steps), dtype=int)

for j in range(M):
    displacements = np.random.randint(-1.0*s, s+1, n_steps-1)
    for i in range(1,n_steps):
        x[j][i] = x[j][i-1] + displacements[i-1]

# %%
y = np.zeros((n_steps))
y_sq = np.zeros((n_steps))
for t in range(n_steps):
    y[t] = x[:,t].mean()
    y_sq[t] = (x[:,t]**2).mean()

    
x_axis = np.arange(n_steps)

plt.figure()
plt.plot(x_axis,y)
plt.plot(x_axis,np.zeros((n_steps)), '--')

plt.ylabel('<d>')
plt.xlabel('t')


plt.figure()
plt.plot(x_axis,y_sq)
plt.plot(x_axis,x_axis)

plt.ylabel('<d^2>')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
#Now, we want to see the full dependence with s and t of <d> and <d^2>

# %%
M = 1000
n_steps = 4000

max_s = 10
s_array = np.arange(1,max_s)

y = np.zeros((max_s-1))
y_sq = np.zeros((max_s-1))
    

for k,s in enumerate(s_array):
    

    x = np.zeros((M,n_steps), dtype=int)

    for j in range(M):
        displacements = np.random.randint(-1.0*s, s+1, n_steps-1)
        for i in range(1,n_steps):
            x[j][i] = x[j][i-1] + displacements[i-1]
    t = n_steps -1
    y[k] = x[:,t].mean()
    y_sq[k] = (x[:,t]**2).mean()

# %%
plt.figure()
plt.plot(s_array, y, 'o-')
plt.ylabel('<d>')
plt.xlabel('s')

plt.figure()
plt.plot(s_array, y_sq, 'o-')
plt.plot(s_array, 0.5*s_array*s_array*t, label=f'y=0.5*s^2*t')
plt.legend(loc='best')
plt.yscale('log')
plt.title(f't={n_steps}')
plt.xscale('log')
plt.ylabel('<d^2>')
plt.xlabel('s')
# Out:
# Text(0.5, 0, 's')

# %%
#Perfect so far, now we need to change paradigm.
#Need to create Class called walker, and the population of walkers is just a list.

# %%
class Position2D():
    def __init__(self, x,y):
        self.x = x
        self.y = y
        return None
    
    def __repr__(self):
        #print(self.x,self.y) 
        return f'x={self.x}, y={self.y}'
    def __add__(p1,p2):
        return Position2D(p1.x+p2.x, p1.y+p2.y)    


class Walker():
    def __init__(self, position):
        self.position = Position2D(position.x, position.y)

    
    def copy(self):
        p = Position2D(self.position.x, self.position.y)
        c = Walker(p)
        return c
    
    def __repr__(self):
        return f'Walker on position {self.position}'

# %%
n_0 = 100
n_steps = 10000



pop_t = {t: [] for t in range(n_steps)}
pop_t[0] = [Walker(Position2D(0,0)) for i in range(n_0)]


for t in range(1, n_steps):
    population = pop_t[t-1]
    
    for walker in population:
        step = 1 #1*np.random.normal(1, 10**-2)
        x, y = np.random.randint(-1.0*step, step+1,2)
        displacement = Position2D(x,y)
        
        
        walker.position = walker.position + displacement
        pop_t[t].append(walker.copy())
    

x = {i: [] for i in range(3)}
y = {i: [] for i in range(3)}

cmap = {0:'blue', 1:'black', 2:'red'}

for t in range(n_steps):
    #plt.plot((0,0), markersize=20)
    for i in range(3):
        x[i].append(pop_t[t][i].position.x)
        y[i].append(pop_t[t][i].position.y)

        
plt.figure()        
for i in range(3):
    
    plt.plot(x[i][:t], y[i][:t], 'o--', c=cmap[i])

#Now see <d> and <d^2>
y = []
y_sq = []
for t in range(n_steps):
    aux = []
    for i in range(len(pop_t[t])):
        pos = pop_t[t][i].position
        aux.append(math.sqrt(pos.x**2 + pos.y**2))
    aux = np.array(aux)
    y.append(aux.mean())
    y_sq.append((aux**2).mean())
  

x = np.arange(0,n_steps)

plt.figure()
plt.plot(x, y, 'o-')
plt.ylabel('<d>')
plt.xlabel('t')

plt.figure()
plt.plot(x, y_sq, 'o-')
plt.plot(x, 0.5*x, label=f'y=0.5*s^2*t')
plt.legend(loc='best')
plt.yscale('log')
plt.xscale('log')
plt.ylabel('<d^2>')
# Out:
# Text(0, 0.5, '<d^2>')

# %%
#Same model but with fitness for each

n_0 = 10
n_steps = 100
N_max = 10**4


f=2

step = 1 #1*np.random.normal(1, 10**-2)

pop_t = {t: [] for t in range(n_steps)}
pop_t[0] = [Walker(Position2D(0,0)) for i in range(n_0)]


for t in range(1, n_steps):
    population = pop_t[t-1]
    aux = []
    
    for walker in population:
        
        for m in range(f):
            w = walker.copy()
        
            
            x, y = np.random.randint(-1.0*step, step+1,2)
            displacement = Position2D(x,y)


            w.position = w.position + displacement
            aux.append(w.copy())
    if len(aux) > N_max:
        pop_t[t] = random.choices(aux, k=N_max)
    else:
        pop_t[t] = aux

# %%
x = {i: [] for i in range(3)}
y = {i: [] for i in range(3)}

cmap = {0:'blue', 1:'black', 2:'red'}

for t in range(n_steps):
    #plt.plot((0,0), markersize=20)
    for i in range(3):
        x[i].append(pop_t[t][i].position.x)
        y[i].append(pop_t[t][i].position.y)

        
plt.figure()        
for i in range(3):
    
    plt.plot(x[i][:t], y[i][:t], 'o--', c=cmap[i])

#Now see <d> and <d^2>
y = []
y_st = []
y_sq = []
for t in range(n_steps):
    aux = []
    for i in range(len(pop_t[t])):
        pos = pop_t[t][i].position
        # aux = [(pos.x, pos.y), (pos.x, pos.y) ... ]
        aux.append(math.sqrt(pos.x**2 + pos.y**2))
    aux = np.array(aux)
    
    y.append(aux.mean())
    y_st.append(aux.std())
    y_sq.append((aux**2).mean())
  

x = np.arange(0,n_steps)
y = np.array(y)
y_st = np.array(y_st)
y_sq = np.array(y_sq)

plt.figure()
plt.plot(x, y, 'o-')
plt.ylabel('<d>')
plt.xlabel('t')
plt.yscale('log')
plt.xscale('log')

plt.figure()
plt.plot(x, y_st**2 / y, 'o-')
plt.ylabel('Disperssion index')
plt.xlabel('t')
#plt.yscale('log')
#plt.xscale('log')

plt.figure()
plt.plot(x, y_sq, 'o-')
plt.plot(x, 0.5*x, label=f'y=0.5*s^2*t')
plt.legend(loc='best')
plt.yscale('log')
plt.xscale('log')
plt.ylabel('<d^2>')
# Out:
# 10
# 20
# 40
# 80
# 160
# 320
# 640
# 1280
# 2560
# 5120
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# /tmp/ipykernel_5378/2766549087.py:48: RuntimeWarning: invalid value encountered in divide
#   plt.plot(x, y_st**2 / y, 'o-')
# Text(0, 0.5, '<d^2>')
