# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(1,10)
y = ((x)**x)/np.array([np.math.factorial(i) for i in x])
y_aster = 1/np.sqrt(2*np.pi*x) * np.e**(x)-1

# %%
plt.plot(x,y)
plt.plot(x,y_aster)
plt.yscale('log')

# %%
# Out:
# array([1.0, 3.5, 9.666666666666666, 25.041666666666668, 63.8,
#        162.4013888888889, 415.1015873015873, 1066.6270089285715,
#        2754.731922398589, 7146.658895778219, 18612.926233766233,
#        48637.8461384701, 127462.00337621226, 334863.627690599,
#        881656.9515664614, -319224.2193323542, 25852.483464946945,
#        -706.9878705820375, 13.300637563878833, 1.1351051429976393,
#        -1.1760963554447594, -0.9939647213340376, -1.0,
#        -1.0000123294080296, -0.9999999113043947, -1.0000000191197693,
#        -1.000000000385472, -0.9999999999764251, -0.9999999999997817],
#       dtype=object)
